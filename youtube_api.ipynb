# %%
pip install youtube-transcript-api google-api-python-client pandas nltk textblob scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Video URLs

# %%
video_urls = [
    "https://www.youtube.com/watch?v=hVQPD5-67vs",
    "https://www.youtube.com/watch?v=Sre35Z1KrNc",
    "https://www.youtube.com/watch?v=ahOgS5ApAeM",
    "https://www.youtube.com/watch?v=MjiLvOmvPKo",
    "https://www.youtube.com/watch?v=lb7boeBb5zU",
    "https://www.youtube.com/watch?v=NF954knwpgA"
]

video_ids = [url.split("v=")[1] for url in video_urls]

# %% [markdown]
# ## Getting Transcripts

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_transcript(video_id):
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        text = " ".join([t['text'] for t in transcript])
        return text
    except:
        return ""

transcripts = {vid: get_transcript(vid) for vid in video_ids}

for vid in video_ids:
    print("\n==============================")
    print("VIDEO ID:", vid)
    print("==============================")
    print(transcripts[vid][:500])  # brings back first 500 chars only
# Out:
# ...
# VIDEO ID: hVQPD5-67vs
# ...
#
#
# ...
# VIDEO ID: Sre35Z1KrNc
# ...
#
#
# ...
# VIDEO ID: ahOgS5ApAeM
# ...
#
#
# ...
# VIDEO ID: MjiLvOmvPKo
# ...
#
#
# ...
# VIDEO ID: lb7boeBb5zU
# ...
#
#
# ...
# VIDEO ID: NF954knwpgA
# ...

# %%
from googleapiclient.discovery import build

api_key = "AIzaSyBpRmSmDVHwnhJ6uNx048sqRf-Ul6gvyhc"
youtube = build("youtube", "v3", developerKey=api_key)

def get_comments(video_id, max_comments=50):
    comments = []
    
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=50
    )
    
    response = request.execute()
    
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
        comments.append(comment)
    
    return comments

comments_data = {vid: get_comments(vid) for vid in video_ids}

for vid in video_ids:
    print("\n==============================")
    print("VIDEO ID:", vid)
    print("==============================")
    for c in comments_data[vid][:5]:  # brings back first 5 comments only
        print("-", c)
# Out:
# ...
# VIDEO ID: hVQPD5-67vs
# ...
# - If you’re preparing for a childcare job, I’ve put together a Job‑Ready bundle with interview answers, resume help and practical examples 👉 <a href="https://payhip.com/b/Rm3JS">https://payhip.com/b/Rm3JS</a><br>This is what I wish I had when I started.
# - What am I suppose to answer to answer when interviewer ask’s me that what is first nation perspective? How should I begin the answer?
# - Please make a video on First Nation Perspective. I want you understand First Nation Perspective from you please
#
# ...
# VIDEO ID: Sre35Z1KrNc
# ...
# - ...what;&#39;s the catch?
# - Work is BS.
# - Elon Musk has warned that AI and robotics could replace a large portion of traditional jobs — especially digital, routine tasks — at a very rapid pace, particularly “desk jobs.” So, please don&#39;t waste your money on USELESS degrees.
# - Im not surprised with police officers.
# - you don&#39;t need a college degree. SEND RESUMES
#
# ...
# VIDEO ID: ahOgS5ApAeM
# ...
# - How can I talk with you?
#
# ...

# %% [markdown]
# ## Preprocess Text

# %%
import re
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    words = text.split()
    words = [w for w in words if w not in stop_words]
    return " ".join(words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/abivandhaanarajesh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
